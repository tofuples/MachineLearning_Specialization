# %% [markdown]
# #### Linear Regression using Scikit-Learn
#
# > Using scikit-learn to implement linear regression using a close form solution based on the normal equation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from lab_utils_multi import load_house_data
np.set_printoptions(precision=2)

# %% [markdown]
# #### Linear Regression, closed-form solution
#
# Let's use the data from the early labs - a house with 1000 square feet sold for \\$300,000 and a house with 2000 square feet sold for \\$500,000.
#
# | Size (1000 sqft)     | Price (1000s of dollars) |
# | ----------------| ------------------------ |
# | 1               | 300                      |
# | 2               | 500                      |

# %% [markdown]
# ### Load the data set

# %%
X_train = np.array([1.0, 2.0])   #features
y_train = np.array([300, 500])   #target value

# %% [markdown]
# #### Create and fit the model

# %%
#creates a regression object.  
linear_model = LinearRegression() 

#Regression, fitting the parameters to the input data.
linear_model.fit(X_train.reshape(-1, 1), y_train)  #X must be a 2-D Matrix
# Out:
# LinearRegression()

# %% [markdown]
# ####  Parameters
# The $\mathbf{w}$ and $\mathbf{b}$ parameters are referred to as 'coefficients' and 'intercept' in scikit-learn.

# %%
b = linear_model.intercept_
w = linear_model.coef_
print(f"w = {w:}, b = {b:0.2f}")
print(f"'manual' prediction: f_wb = wx+b : {1200*w + b}")
# Out:
# w = [200.], b = 100.00
# 'manual' prediction: f_wb = wx+b : [240100.]

# %% [markdown]
# #### Predictions

# %%
y_pred = linear_model.predict(X_train.reshape(-1, 1))

print("Prediction on training set:", y_pred)

X_test = np.array([[1200]])
print(f"Prediction for 1200 sqft house: ${linear_model.predict(X_test)[0]:0.2f}")
# Out:
# Prediction on training set: [300. 500.]
# Prediction for 1200 sqft house: $240100.00

# %% [markdown]
# ### Second Example
# Example from an earlier lab with multiple features (lab2-week2). The final parameter values and predictions are very close to the results from the un-normalized 'long-run' from that lab. That un-normalized run took hours to produce results, while this is nearly instantaneous.
#
# The closed-form solution work well on smaller data sets such as these but can be computationally demanding on larger data sets.

# %%
# load the dataset
X_train, y_train = load_house_data()
X_features = ['size(sqft)','bedrooms','floors','age']

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)

# %%
b = linear_model.intercept_
w = linear_model.coef_
print(f"w = {w:}, b = {b:0.2f}")

# %%
print(f"Prediction on training set:\n {linear_model.predict(X_train)[:4]}" )
print(f"prediction using w,b:\n {(X_train @ w + b)[:4]}")
print(f"Target values \n {y_train[:4]}")

x_house = np.array([1200, 3,1, 40]).reshape(-1,4)
x_house_predict = linear_model.predict(x_house)[0]
print(f" predicted price of a house with 1200 sqft, 3 bedrooms, 1 floor, 40 years old = ${x_house_predict*1000:0.2f}")
